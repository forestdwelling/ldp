# %%
import pandas as pd

df = pd.read_csv('export.csv', 
    dtype={'user_id':str, 'sex':str, 'country':str, 'checkin_date':object, 'trackable_type':str, 'trackable_name':str}, 
    parse_dates=['checkin_date'], 
    infer_datetime_format=True)
df.head(5)
# Out:
# /home/wangfayao/anaconda3/envs/ldp/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                             user_id   age     sex country checkin_date  \
# 0  QEVuQwEABlEzkh7fsBBjEe26RyIVcg==   NaN     NaN     NaN   2015-11-26
# 1  QEVuQwEAWRNGnuTRqXG2996KSkTIEw==  32.0    male      US   2015-11-26
# 2  QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   2.0  female      CA   2017-04-28
# 3  QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   2.0  female      CA   2017-04-28
# 4  QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   2.0  female      CA   2017-04-28
#
#   trackable_id trackable_type  \
# 0         1069      Condition
# 1         1069      Condition
# 2         3168      Condition
# 3         3169      Condition
# 4         3170      Condition
#
#                                       trackable_name trackable_value
# ...

# %%
df.drop(['sex', 'country', 'trackable_id', 'trackable_type', 'trackable_name', 'trackable_value'], axis=1, inplace=True)
df.head(5)
# Out:
#                             user_id   age checkin_date
# 0  QEVuQwEABlEzkh7fsBBjEe26RyIVcg==   NaN   2015-11-26
# 1  QEVuQwEAWRNGnuTRqXG2996KSkTIEw==  32.0   2015-11-26
# 2  QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   2.0   2017-04-28
# 3  QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   2.0   2017-04-28
# 4  QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   2.0   2017-04-28

# %%
df.dropna(inplace=True)
df['id'] = df.user_id.astype('category').cat.codes
df.head(5)
# Out:
#                             user_id   age checkin_date     id
# 1  QEVuQwEAWRNGnuTRqXG2996KSkTIEw==  32.0   2015-11-26  21865
# 2  QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   2.0   2017-04-28    359
# 3  QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   2.0   2017-04-28    359
# 4  QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   2.0   2017-04-28    359
# 5  QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   2.0   2017-04-28    359

# %%
df = df[(df['age'] > 0) & (df['age']<)]
# Out:
# count    7.666997e+06
# mean     3.506967e+01
# std      1.437926e+02
# min     -1.966910e+05
# 25%      2.600000e+01
# 50%      3.400000e+01
# 75%      4.300000e+01
# max      2.018000e+03
# Name: age, dtype: float64
